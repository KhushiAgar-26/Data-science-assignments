# %% [markdown]
# # EXPLORATORY DATA ANALYSIS ON A DATASET

# %% [markdown]
# ### Objective:
# The main goal of this assignment is to conduct a thorough exploratory analysis of the "cardiographic.csv" dataset to uncover insights, identify patterns, and understand the dataset's underlying structure. You will use statistical summaries, visualizations, and data manipulation techniques to explore the dataset comprehensively.
# in the FHR.

# %% [markdown]
# ### Dataset:
#
# 1.	LB - Likely stands for "Baseline Fetal Heart Rate (FHR)" which represents the average fetal heart rate over a period.
# 2.	AC - Could represent "Accelerations" in the FHR. Accelerations are usually a sign of fetal well-being.
# 3.	FM - May indicate "Fetal Movements" detected by the monitor.
# 4.	UC - Likely denotes "Uterine Contractions", which can impact the FHR pattern.
# 5.	DL - Could stand for "Decelerations Late" with respect to uterine contractions, which can be a sign of fetal distress.
# 6.	DS - May represent "Decelerations Short" or decelerations of brief duration.
# 7.	DP - Could indicate "Decelerations Prolonged", or long-lasting decelerations.
# 8.	ASTV - Might refer to "Percentage of Time with Abnormal Short Term Variability" in the FHR.
# 9.	MSTV - Likely stands for "Mean Value of Short Term Variability" in the FHR.
# 10.	ALTV - Could represent "Percentage of Time with Abnormal Long Term Variability" in the FHR.
# 11.	MLTV - Might indicate "Mean Value of Long Term Variability" in the FHR.

# %% [markdown]
# ### Importing Basic Dependencies

# %% [markdown]
# ## Tasks:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 1. Data Cleaning and Preparation:

# %%
df=pd.read_csv('Cardiotocographic.csv')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.shape # shape(row,columns)
# Out:
# (2126, 14)

# %%
df.columns  # check the columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df.info()  # this function gives the information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.describe()  # this function does the basis statitics of data
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %% [markdown]
# ## Duplicates

# %%
#Count of duplicated rows
df[df.duplicated()].shape
# Out:
# (2, 14)

# %%
df[df.duplicated()]   #Print the duplicated rows
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %% [markdown]
# #### drop the duplicate values

# %%
df1=df.drop_duplicates()

# %%
df1.shape # df1  after drop of duplicated values
# Out:
# (2124, 14)

# %%
 df.shape  # before drop duplicate data
# Out:
# (2126, 14)

# %% [markdown]
# ##  Missing Values and Imputation

# %%
df1.isnull()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
# 2124  False  False  False  False  False  False  False  False  False  False
# 2125  False  False  False  False  False  False  False  False  False  False
#
#        MLTV  Width  Tendency    NSP
# ...

# %%
df1.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
len(df1)
# Out:
# 2124

# %%
df1.isnull().sum()*100/len(df1)
# Out:
# LB          0.988701
# AC          0.941620
# FM          0.000000
# UC          0.000000
# DL          0.000000
# DS          0.988701
# DP          0.988701
# ASTV        0.000000
# MSTV        0.000000
# ALTV        0.000000
# MLTV        0.988701
# Width       0.988701
# Tendency    0.988701
# NSP         0.988701
# dtype: float64

# %%
plt.figure(figsize=(12,6))

cols = df1.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df1[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
df1[df1.isnull().any(axis = 1)]
# Out:
#       LB        AC        FM        UC        DL  DS  DP       ASTV      MSTV  \
# 50   NaN       NaN  0.000000  0.008086  0.000000 NaN NaN  29.000000  1.300000
# 116  NaN  0.038567  0.000000  0.006993  0.002331 NaN NaN  26.000000  4.300000
# 126  NaN       NaN  0.000000  0.004380  0.000000 NaN NaN  69.000000  0.300000
# 201  NaN       NaN  0.016393  0.000000  0.000000 NaN NaN  56.000000  0.500000
# 566  NaN       NaN  0.000000  0.004115  0.005487 NaN NaN  43.000000  2.500000
# 574  NaN       NaN  0.000000  0.002611  0.002611 NaN NaN  34.000000  4.900000
# 603  NaN       NaN  0.006519  0.001304  0.001304 NaN NaN  73.000000  0.700000
# 935  NaN       NaN  0.000000  0.005495  0.001374 NaN NaN  30.000000  1.251793
# 936  NaN       NaN  0.000000  0.007802  0.000000 NaN NaN  33.000000  1.000000
# 1013 NaN       NaN  0.000000  0.003861  0.000000 NaN NaN  34.000000  1.000000
# 1205 NaN       NaN -0.000129  0.006424  0.000000 NaN NaN  63.000000  0.500000
# ...

# %%
df1[df1.isnull().any(axis = 1)].shape
# Out:
# (21, 14)

# %%
median = df1['LB'].median()
median
# Out:
# 133.0

# %%
df1['LB'] = df1['LB'].fillna(median)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4504\1151221799.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['LB'] = df1['LB'].fillna(median)

# %%
mean= df1['DS'].mean()
mean
# Out:
# 2.511369605097549e-06

# %%
mean1= df1['DP'].mean()
mean1
# Out:
# 0.00017531778446317666

# %%
df1['DS'] = df1['DS'].fillna(mean)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4504\1715184153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DS'] = df1['DS'].fillna(mean)

# %%
df1['DP'] = df1['DP'].fillna(mean1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4504\3458227074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DP'] = df1['DP'].fillna(mean1)

# %%
median1 = df1['AC'].median()
median1
# Out:
# 0.001633991

# %%
df1['AC'] = df1['AC'].fillna(median)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4504\2543763064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['AC'] = df1['AC'].fillna(median)

# %%
median2 = df1['MLTV'].median()
median2
# Out:
# 7.4

# %%
median3 = df1['Width'].median()
median3
# Out:
# 67.48646809530248

# %%
mean = df1['Tendency'].mean()
mean
# Out:
# 0.31667228014592036

# %%
median5 = df1['NSP'].median()
median5
# Out:
# 1.0

# %%
df1['MLTV'] = df1['MLTV'].fillna(median)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4504\1677356145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['MLTV'] = df1['MLTV'].fillna(median)

# %%
df1['Width'] = df1['Width'].fillna(median)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4504\1002708120.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Width'] = df1['Width'].fillna(median)

# %%
df1['Tendency'] = df1['Tendency'].fillna(median)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4504\2867474340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Tendency'] = df1['Tendency'].fillna(median)

# %%
df1['NSP'] = df1['NSP'].fillna(median)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4504\2068400487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['NSP'] = df1['NSP'].fillna(median)

# %%
df1[df1.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [LB, AC, FM, UC, DL, DS, DP, ASTV, MSTV, ALTV, MLTV, Width, Tendency, NSP]
# Index: []

# %%
df1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# ## Outlier Detection

# %%
df1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# ## LB

# %%
# histogram of LB
df1['LB'].hist()
# Out:
# <Axes: >

# %%
df1.LB.skew()
# Out:
# 0.3235694716128613

# %%
df.boxplot('LB')
# Out:
# <Axes: >

# %%
df1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
print(df1['LB'].isnull().sum())
# Out:
# 0

# %%
print(df1['LB'].describe())
# Out:
# count    2124.000000
# mean      133.338641
# std        11.212447
# min        51.842487
# 25%       126.000000
# 50%       133.000000
# 75%       140.000000
# max       214.000000
# Name: LB, dtype: float64

# %%
#trimming the outliers
Q1 = df1['LB'].quantile(0.25)
Q3 = df1['LB'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers
df_filtered = df1[(df1['LB'] >= lower_bound) & (df1['LB'] <= upper_bound)]

# %%
df_filtered['LB'].hist()  #  df1['LB'].hist()
# Out:
# <Axes: >

# %%
df_filtered['LB'].skew()
# Out:
# 0.008076992030987629

# %%
# histogram of FM
df1['AC'].hist()
# Out:
# <Axes: >

# %%
# histogram of FM
df1['FM'].hist()
# Out:
# <Axes: >

# %%
# histogram of UC
df1['UC'].hist()
# Out:
# <Axes: >

# %%
# histogram of DL
df1['DL'].hist()
# Out:
# <Axes: >

# %%
# histogram of DS
df1['DS'].hist()
# Out:
# <Axes: >

# %%
# histogram of DP
df1['DP'].hist()
# Out:
# <Axes: >

# %%
# histogram of ASTV
df1['ASTV'].hist()
# Out:
# <Axes: >

# %%
df.boxplot('ASTV')
# Out:
# <Axes: >

# %%
#trimming the outliers
Q1 = df1['ASTV'].quantile(0.25)
Q3 = df1['ASTV'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers
df_filtered = df1[(df1['ASTV'] >= lower_bound) & (df1['ASTV'] <= upper_bound)]

# %%
df_filtered.shape
# Out:
# (2114, 14)

# %%
df_filtered.ASTV.hist()
# Out:
# <Axes: >

# %%
# histogram of MSTV
df1['MSTV'].hist()
# Out:
# <Axes: >

# %%
# histogram of ALTV
df1['ALTV'].hist()
# Out:
# <Axes: >

# %%
# histogram of MLTV
df1['MLTV'].hist()
# Out:
# <Axes: >

# %%
df.boxplot('MLTV')
# Out:
# <Axes: >

# %%
#trimming the outliers
Q1 = df1['MLTV'].quantile(0.25)
Q3 = df1['MLTV'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers
df_filtered = df1[(df1['MLTV'] >= lower_bound) & (df1['MLTV'] <= upper_bound)]

# %%
df_filtered.MLTV.hist()
# Out:
# <Axes: >

# %% [markdown]
# ## 2.	Statistical Summary:

# %%
df1.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean    133.338641     1.255544     0.009904     0.004394     0.001897
# std      11.212447    12.847741     0.067571     0.003340     0.003344
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001858     0.000000
# 50%     133.000000     0.001668     0.000000     0.004486     0.000000
# 75%     140.000000     0.005838     0.002568     0.006536     0.003292
# max     214.000000   133.000000     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean      0.000003     0.000175    47.012459     1.364345    10.295650
# std       0.000141     0.000836    18.812403     1.174084    21.212676
# ...

# %% [markdown]
# ### ●	Provide a statistical summary for each variable in the dataset, including measures of central tendency (mean, median) and dispersion (standard deviation, interquartile range).

# %% [markdown]
# ## MEAN

# %%
# Calculate the mean of each column
column_means= df1.mean()

# Display the mean of each column
print("Mean of each column:")
print(column_means)
# Out:
# Mean of each column:
# LB          133.338641
# AC            1.255544
# FM            0.009904
# UC            0.004394
# DL            0.001897
# DS            0.000003
# DP            0.000175
# ASTV         47.012459
# MSTV          1.364345
# ALTV         10.295650
# MLTV          9.513648
# Width        71.079375
# Tendency      1.628513
# NSP           2.606868
# dtype: float64

# %% [markdown]
# ## MEDIAN

# %%
# Calculate the median of each column
column_means = df1.median()

# Display the median of each column
print("Median of each column:")
print(column_medians)
# Out:
# Median of each column:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 6
#       4 # Display the median of each column
#       5 print("Median of each column:")
# ----> 6 print(column_medians)
#
# NameError: name 'column_medians' is not defined

# %% [markdown]
# ## STANDARD DEVIATION

# %%
# Calculate the standard deviation of each column
column_std = df1.std()

# Display the standard deviation of each column
print("standard deviation  of each column:")
print(column_std)

# %% [markdown]
# ## IQR

# %%
import numpy as np

# Calculate the 25th and 75th percentiles for each column
q25 = df1.quantile(0.25)
q75 = df1.quantile(0.75)

# Calculate the interquartile range (IQR) for each column
column_iqr = q75 - q25

# Display the interquartile range (IQR) for each column
print("Interquartile range (IQR) for each column:")
print(column_iqr)

# %%
df1.describe()

# %% [markdown]
# ## 3.	Data Visualization:

# %%
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
for col in num_cols:
    plt.figure(figsize=(8, 6))
    sns.histplot(df[col], bins=20, kde=True)
    plt.title(col)
    plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df1.hist(bins=20, figsize=(10, 6))
plt.suptitle('Histograms of Numerical Variables', y=1.02)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
df1.boxplot()
plt.title('Boxplots of Numerical Variables')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.pairplot(df1)

# %%
df1.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.002967  0.018839 -0.166669 -0.126585 -0.005439
# AC       -0.002967  1.000000 -0.009761  0.005575  0.008788 -0.000011
# FM        0.018839 -0.009761  1.000000 -0.053386  0.009641  0.029896
# UC       -0.166669  0.005575 -0.053386  1.000000  0.189737 -0.006942
# DL       -0.126585  0.008788  0.009641  0.189737  1.000000  0.058429
# DS       -0.005439 -0.000011  0.029896 -0.006942  0.058429  1.000000
# DP       -0.047726 -0.000028  0.121248  0.070348  0.144853  0.004282
# ASTV      0.241667  0.004762 -0.032838 -0.182379 -0.069907  0.008414
# MSTV     -0.169310  0.017343  0.017061  0.189685  0.410216  0.016079
# ALTV      0.210769 -0.030644 -0.012005 -0.227881 -0.187275 -0.004400
# MLTV     -0.004270  0.826688 -0.011936 -0.018164 -0.079782  0.018252
# Width    -0.117585  0.139949  0.094655  0.106758  0.405531  0.040409
# Tendency  0.008576  0.974515 -0.011116  0.005839  0.008054 -0.000753
# ...

# %%
sns.heatmap(df1.corr(), cmap="YlGnBu",annot = True)
# Out:
# <Axes: >

# %%
plt.violinplot(df1['LB'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x27c68062d90>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x27c60de89d0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x27c60e2fb90>,
#  'cbars': <matplotlib.collections.LineCollection at 0x27c64d37610>}

# %% [markdown]
# ## 4.	Pattern Recognition and Insights:

# %%
# Correlation analysis
correlation_matrix = df1.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
df1.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.002967  0.018839 -0.166669 -0.126585 -0.005439
# AC       -0.002967  1.000000 -0.009761  0.005575  0.008788 -0.000011
# FM        0.018839 -0.009761  1.000000 -0.053386  0.009641  0.029896
# UC       -0.166669  0.005575 -0.053386  1.000000  0.189737 -0.006942
# DL       -0.126585  0.008788  0.009641  0.189737  1.000000  0.058429
# DS       -0.005439 -0.000011  0.029896 -0.006942  0.058429  1.000000
# DP       -0.047726 -0.000028  0.121248  0.070348  0.144853  0.004282
# ASTV      0.241667  0.004762 -0.032838 -0.182379 -0.069907  0.008414
# MSTV     -0.169310  0.017343  0.017061  0.189685  0.410216  0.016079
# ALTV      0.210769 -0.030644 -0.012005 -0.227881 -0.187275 -0.004400
# MLTV     -0.004270  0.826688 -0.011936 -0.018164 -0.079782  0.018252
# Width    -0.117585  0.139949  0.094655  0.106758  0.405531  0.040409
# Tendency  0.008576  0.974515 -0.011116  0.005839  0.008054 -0.000753
# ...

# %% [markdown]
# ##### Strong positive correlations suggest variables move in the same direction, while strong negative correlations suggest they move in opposite directions.

# %%
time_columns = ['ALTV', 'ASTV']

# Convert time columns to datetime
for col in time_columns:
    df[col] = pd.to_datetime(df[col])

# Set 'ALTV' and 'ASTV' as index (if needed)
# df.set_index(['ALTV', 'ASTV'], inplace=True)

# Plot time series data
for col in time_columns:
    plt.figure(figsize=(10, 6))
    plt.plot(df[col], df.index)
    plt.xlabel(col)
    plt.ylabel('Timestamp')
    plt.title(f'Trend of {col} over Time')
    plt.show()

# %% [markdown]
# ### conclusion
# #Baseline Fetal Heart Rate (FHR) has positive correlaton with Percentage of Time with Abnormal Short Term Variability and negative correlation with Accelerations #"Uterine Contractions and Decelerations Late" have postive correlation
